# %%
import pandas as pd
cancer = pd.read_csv("Lung Cancer.csv")
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### dropping duplicates
cancer.drop_duplicates()
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### checking data types
cancer.dtypes
# Out:
# id                      int64
# age                   float64
# gender                 object
# country                object
# diagnosis_date         object
# cancer_stage           object
# family_history         object
# smoking_status         object
# bmi                   float64
# cholesterol_level       int64
# hypertension            int64
# asthma                  int64
# cirrhosis               int64
# other_cancer            int64
# treatment_type         object
# end_treatment_date     object
# survived                int64
# dtype: object

# %%
### checking null values
cancer.isna().sum()
# Out:
# id                    0
# age                   0
# gender                0
# country               0
# diagnosis_date        0
# cancer_stage          0
# family_history        0
# smoking_status        0
# bmi                   0
# cholesterol_level     0
# hypertension          0
# asthma                0
# cirrhosis             0
# other_cancer          0
# treatment_type        0
# end_treatment_date    0
# survived              0
# dtype: int64

# %%
### checking unique values
cancer["smoking_status"].unique()
# Out:
# array(['Passive Smoker', 'Former Smoker', 'Never Smoked',
#        'Current Smoker'], dtype=object)

# %%
### checking smoking status for all patients
cancer["smoking_status"].value_counts()
# Out:
# smoking_status
# Passive Smoker    223170
# Never Smoked      222751
# Former Smoker     222181
# Current Smoker    221898
# Name: count, dtype: int64

# %%
### checking the number of males and females
cancer["gender"].value_counts()
# Out:
# gender
# Male      445134
# Female    444866
# Name: count, dtype: int64

# %%
### checking all unique countries in the data
cancer["country"].unique()
# Out:
# array(['Sweden', 'Netherlands', 'Hungary', 'Belgium', 'Luxembourg',
#        'Italy', 'Croatia', 'Denmark', 'Malta', 'Germany', 'Poland',
#        'Ireland', 'Romania', 'Spain', 'Greece', 'Estonia', 'Cyprus',
#        'France', 'Slovenia', 'Latvia', 'Portugal', 'Austria',
#        'Czech Republic', 'Finland', 'Lithuania', 'Slovakia', 'Bulgaria'],
#       dtype=object)

# %%
### checking the number of patients from each country
cancer["country"].value_counts()
# Out:
# country
# Malta             33367
# Ireland           33243
# Portugal          33208
# France            33199
# Sweden            33161
# Croatia           33138
# Greece            33052
# Spain             33042
# Netherlands       33040
# Denmark           33024
# Slovenia          33005
# Belgium           32986
# Hungary           32981
# Romania           32963
# Poland            32949
# Italy             32948
# Germany           32940
# Estonia           32893
# Czech Republic    32885
# Lithuania         32856
# Slovakia          32853
# Austria           32832
# Finland           32798
# Luxembourg        32794
# Cyprus            32719
# Latvia            32565
# Bulgaria          32559
# Name: count, dtype: int64

# %%
### checking unique treatment types
cancer["treatment_type"].unique()
# Out:
# array(['Chemotherapy', 'Surgery', 'Combined', 'Radiation'], dtype=object)

# %%
### checking the number of patients with their treatment type
cancer["treatment_type"].value_counts()
# Out:
# treatment_type
# Chemotherapy    223262
# Surgery         223261
# Combined        222609
# Radiation       220868
# Name: count, dtype: int64

# %%
### checking the number of survials
cancer["survived"].value_counts()
# Out:
# survived
# 0    693996
# 1    196004
# Name: count, dtype: int64

# %%
### checking the stage of cancer of each patient 
cancer["cancer_stage"].value_counts()
# Out:
# cancer_stage
# Stage III    222594
# Stage IV     222527
# Stage I      222516
# Stage II     222363
# Name: count, dtype: int64

# %%
### checking unique age 
cancer["age"].unique()
# Out:
# array([ 64.,  50.,  65.,  51.,  37.,  49.,  56.,  48.,  47.,  67.,  45.,
#         46.,  21.,  62.,  60.,  57.,  36.,  61.,  71.,  74.,  35.,  54.,
#         44.,  68.,  59.,  58.,  63.,  69.,  70.,  52.,  40.,  78.,  75.,
#         72.,  42.,  53.,  39.,  66.,  41.,  43.,  55.,  38.,  30.,  34.,
#         76.,  73.,  80.,  31.,  85.,  28.,  79.,  87.,  77.,  33.,  32.,
#         25.,  90.,  84.,  81.,  27.,  82.,  83.,  22.,  86.,  26.,  93.,
#         29.,  23.,  19.,  24.,  89.,  18.,  91.,  95.,  88.,  20.,  94.,
#        101.,  15.,  92.,  16.,  17.,  10.,  14.,  99.,  13.,  97.,   9.,
#         12.,  98.,   7.,  96.,   4., 104.,   8.])

# %%
### dividing the age into 4 age groups 
import numpy as np
cancer["age_group"] = np.where((cancer["age"] > 0) & (cancer["age"] <= 15),"Children",
                        np.where((cancer["age"] >= 16) & (cancer["age"] <= 25),"Teenegars",
                        np.where((cancer["age"] >25 ) & (cancer["age"] <= 59),"Adult","Old")))
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### checking how many patient across all age group
cancer["age_group"].value_counts()
# Out:
# age_group
# Adult        597822
# Old          290742
# Teenegars      1401
# Children         35
# Name: count, dtype: int64

# %%
### using bmi to categorise all patient weight 
cancer["weight"] = np.where((cancer["bmi"] > 0) & (cancer["bmi"] < 18.5),"Underweight",
                        np.where((cancer["bmi"] >= 18.5) & (cancer["bmi"] <= 24.9),"Normal weight",
                        np.where((cancer["bmi"] > 24.9 ) & (cancer["bmi"] <= 29.9),"Overweight","Obese")))
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### categorising cholesteral level of all patients 
cancer["Cholesterol_status"] = np.where((cancer["cholesterol_level"] > 0) & (cancer["cholesterol_level"] < 200),"low",
                        np.where((cancer["cholesterol_level"] >= 200) & (cancer["cholesterol_level"] <= 239),"medium",
                        np.where((cancer["cholesterol_level"] >=240) & (cancer["cholesterol_level"] <=400),"high","")))
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### cheking patients and their weight
cancer["weight"].value_counts()
# Out:
# weight
# Obese            461727
# Normal weight    199482
# Overweight       153483
# Underweight       75308
# Name: count, dtype: int64

# %%
### checking hypertension patients
cancer["hypertension"].value_counts()
# Out:
# hypertension
# 1    667521
# 0    222479
# Name: count, dtype: int64

# %%
### checking asthmatic patients 
cancer["asthma"].value_counts()
# Out:
# asthma
# 0    471931
# 1    418069
# Name: count, dtype: int64

# %%
### checking patients with cirrhosis
cancer["cirrhosis"].value_counts()
# Out:
# cirrhosis
# 0    688899
# 1    201101
# Name: count, dtype: int64

# %%
### checking patients with other cancers 
cancer["other_cancer"].value_counts()
# Out:
# other_cancer
# 0    811540
# 1     78460
# Name: count, dtype: int64

# %%
### checking patients with family history of cancer 
cancer["family_history"].value_counts()
# Out:
# family_history
# No     445181
# Yes    444819
# Name: count, dtype: int64

# %%
### converting the diagnosis_date from object to date and time fomart 
cancer["diagnosis_date"] = cancer["diagnosis_date"].astype("datetime64[ns]")
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### converting the end_treatment_date t0 date and time fomart
cancer["end_treatment_date"] = cancer["end_treatment_date"].astype("datetime64[ns]")
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# ...

# %%
### getting the number of days of treatment for all patients 
cancer["NUM_OF_DAYS_TREATMENT"] = cancer["end_treatment_date"] - cancer["diagnosis_date"]
cancer
# Out:
#             id   age  gender      country diagnosis_date cancer_stage  \
# 0            1  64.0    Male       Sweden     2016-04-05      Stage I
# 1            2  50.0  Female  Netherlands     2023-04-20    Stage III
# 2            3  65.0  Female      Hungary     2023-04-05    Stage III
# 3            4  51.0  Female      Belgium     2016-02-05      Stage I
# 4            5  37.0    Male   Luxembourg     2023-11-29      Stage I
# ...        ...   ...     ...          ...            ...          ...
# 889995  889996  40.0    Male        Malta     2022-07-01     Stage IV
# 889996  889997  62.0  Female       Cyprus     2015-09-27     Stage II
# 889997  889998  48.0  Female      Estonia     2016-03-27    Stage III
# 889998  889999  67.0  Female     Slovakia     2015-12-22     Stage IV
# 889999  890000  55.0  Female        Malta     2021-07-26     Stage II
#
#        family_history  smoking_status   bmi  cholesterol_level  ...  asthma  \
# ...

# %%
from plotly.offline import init_notebook_mode
import cufflinks as cf 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
### age distribution across all patients
cancer.groupby(["age_group"])["id"].count().reset_index()
# Out:
#    age_group      id
# 0      Adult  597822
# 1   Children      35
# 2        Old  290742
# 3  Teenegars    1401

# %%
import matplotlib.pyplot as plt

# %%
### weight and their number of patients
b=cancer.groupby(["weight"])["id"].count().reset_index()
b
# Out:
#           weight      id
# 0  Normal weight  199482
# 1          Obese  461727
# 2     Overweight  153483
# 3    Underweight   75308

# %%
### smoking status across all patients
c=cancer.groupby(["smoking_status"])["id"].count().reset_index()
c
# Out:
#    smoking_status      id
# 0  Current Smoker  221898
# 1   Former Smoker  222181
# 2    Never Smoked  222751
# 3  Passive Smoker  223170

# %%
### asthma and the survival rate
cb=cancer.groupby(["asthma"])["survived"].value_counts().reset_index()
cb
# Out:
#    asthma  survived   count
# 0       0         0  367665
# 1       0         1  104266
# 2       1         0  326331
# 3       1         1   91738

# %%
### cirrhosis and survival rate
cd=cancer.groupby(["cirrhosis"])["survived"].value_counts().reset_index()
cd
# Out:
#    cirrhosis  survived   count
# 0          0         0  537485
# 1          0         1  151414
# 2          1         0  156511
# 3          1         1   44590

# %%
### other_cancer and their survival rate
ce=cancer.groupby(["other_cancer"])["survived"].value_counts().reset_index()
ce
# Out:
#    other_cancer  survived   count
# 0             0         0  632609
# 1             0         1  178931
# 2             1         0   61387
# 3             1         1   17073

# %%
### cholesterol status across all patients 
ca=cancer.groupby(["Cholesterol_status"])["id"].count().reset_index()
ca
# Out:
#   Cholesterol_status      id
# 0               high  461060
# 1                low  237408
# 2             medium  191532

# %%
### survival rate across gender
cv=cancer.groupby(["gender"])["survived"].value_counts().reset_index()
cv
# Out:
#    gender  survived   count
# 0  Female         0  347034
# 1  Female         1   97832
# 2    Male         0  346962
# 3    Male         1   98172

# %%
### survival rate across all cancer stages
cvd=cancer.groupby(["cancer_stage"])["survived"].value_counts().reset_index()
cvd
# Out:
#   cancer_stage  survived   count
# 0      Stage I         0  173978
# 1      Stage I         1   48538
# 2     Stage II         0  173245
# 3     Stage II         1   49118
# 4    Stage III         0  173506
# 5    Stage III         1   49088
# 6     Stage IV         0  173267
# 7     Stage IV         1   49260

# %%
# Assuming your value_counts column is named 0 after reset_index
cvd.columns = ["cancer_stage", "survived", "count"]

# %%
# Pivot the data for plotting
stage = cvd.pivot(index="cancer_stage", columns="survived", values="count").fillna(0)
stage
# Out:
# survived           0      1
# cancer_stage
# Stage I       173978  48538
# Stage II      173245  49118
# Stage III     173506  49088
# Stage IV      173267  49260

# %%
# Plot as a grouped bar chart
stage.plot(kind="bar", figsize=(6, 3))

plt.title("Survival Counts by Cancer Stage")
plt.xlabel("Cancer Stage")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No (0)", "Yes (1)"])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
### survival rate for cholesterol status
cf=cancer.groupby(["Cholesterol_status"])["survived"].value_counts().reset_index()
cf

# %%
# Assuming your value_counts column is named 0 after reset_index
cf.columns = ["Cholesterol_status", "survived", "count"]

# %%
# Pivot the data for plotting
cholesterol = cf.pivot(index="Cholesterol_status", columns="survived", values="count").fillna(0)
cholesterol
# Out:
# survived                 0       1
# Cholesterol_status
# high                359453  101607
# low                 185135   52273
# medium              149408   42124

# %%
# Plot as a grouped bar chart
cholesterol.plot(kind="bar", figsize=(6, 3))

plt.title("Survival Counts by cholesterol")
plt.xlabel("Cholesterol Status")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No (0)", "Yes (1)"])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
### survival rate for different weight 
ac=cancer.groupby(["weight"])["survived"].value_counts().reset_index()
ac

# %%
### Assuming your value_counts column is named 0 after reset_index
ac.columns = ["weight", "survived", "count"]

# %%
### pivot the data for plotting
weight = ac.pivot(index="weight", columns="survived", values="count").fillna(0)
weight
# Out:
# survived            0       1
# weight
# Normal weight  155488   43994
# Obese          360005  101722
# Overweight     119703   33780
# Underweight     58800   16508

# %%
# Plot as a grouped bar chart
weight.plot(kind="bar", figsize=(6, 3))

plt.title("Survival Counts by weight")
plt.xlabel("weight")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No (0)", "Yes (1)"])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
### checking treatment type and their survival rate 
a=cancer.groupby(["treatment_type"])["survived"].value_counts().reset_index()
a

# %%
# Assuming your value_counts column is named 0 after reset_index
a.columns = ["treatment_type", "survived", "count"]

# %%
### pivot the data for plotting
treatment = a.pivot(index="treatment_type", columns="survived", values="count").fillna(0)
treatment
# Out:
# survived             0      1
# treatment_type
# Chemotherapy    174426  48836
# Combined        173607  49002
# Radiation       172154  48714
# Surgery         173809  49452

# %%
# Plot as a grouped bar chart
treatment.plot(kind="bar", figsize=(6, 3))

plt.title("Survival Counts by Treatment")
plt.xlabel("weight")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No (0)", "Yes (1)"])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
### checking survival rate across all age group
b=cancer.groupby(["age_group"])["survived"].value_counts().reset_index()
b
# Out:
#    age_group  survived   count
# 0      Adult         0  466342
# 1      Adult         1  131480
# 2   Children         0      27
# 3   Children         1       8
# 4        Old         0  226550
# 5        Old         1   64192
# 6  Teenegars         0    1077
# 7  Teenegars         1     324

# %%
# Assuming your value_counts column is named 0 after reset_index
b.columns = ["age_group", "survived", "count"]

# %%
### pivot the data for plotting
age = b.pivot(index="age_group", columns="survived", values="count").fillna(0)
age
# Out:
# survived        0       1
# age_group
# Adult      466342  131480
# Children       27       8
# Old        226550   64192
# Teenegars    1077     324

# %%
# Plot as a grouped bar chart
age.plot(kind="bar", figsize=(6, 3))

plt.title("Survival Counts by age_group")
plt.xlabel("weight")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No (0)", "Yes (1)"])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
### smoking status and their survival rate
cc=cancer.groupby(["smoking_status"])["survived"].value_counts().reset_index()
cc

# %%
# Assuming your value_counts column is named 0 after reset_index
cc.columns = ["smoking_status", "survived", "count"]

# %%
### pivot the data for plotting
smoking= cc.pivot(index="smoking_status", columns="survived", values="count").fillna(0)
smoking
# Out:
# survived             0      1
# smoking_status
# Current Smoker  173005  48893
# Former Smoker   173381  48800
# Never Smoked    173543  49208
# Passive Smoker  174067  49103

# %%
# Plot as a grouped bar chart
smoking.plot(kind="bar", figsize=(6, 3))

plt.title("Survival Counts by smoking_status")
plt.xlabel("weight")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No (0)", "Yes (1)"])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
